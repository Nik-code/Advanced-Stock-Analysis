# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

# %%
# Check contents of the data directory
data_path = '../data'

# %%
# Function to load all CSV files from a directory
def load_csv_files(directory):
    dataframes = {}
    for filename in os.listdir(directory):
        if filename.endswith('.csv'):
            file_path = os.path.join(directory, filename)
            df = pd.read_csv(file_path)
            stock_code = filename.split('.')[0]  # Assuming filenames are like '500002.csv'
            dataframes[stock_code] = df
    return dataframes

# %%
# Load all CSV files
all_data = load_csv_files(data_path)

print(f"Total number of stocks loaded: {len(all_data)}")
# Out:
# Total number of stocks loaded: 4142

# %%
# Display basic info for the first few dataframes
for i, (stock_code, df) in enumerate(all_data.items()):
    print(f"\nStock Code: {stock_code}")
    print(df.info())
    print("\n" + "="*50)
    if i == 4:  # Only show the first 5 stocks
        break
# Out:
# Stock Code: 500033
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2473 entries, 0 to 2472
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       2473 non-null   object
#  1   Open Price                 2473 non-null   float64
#  2   High Price                 2473 non-null   float64
#  3   Low Price                  2473 non-null   float64
#  4   Close Price                2473 non-null   float64
#  5   WAP                        2473 non-null   float64
#  6   No.of Shares               2473 non-null   int64
#  7   No. of Trades              2473 non-null   int64
#  8   Total Turnover (Rs.)       2473 non-null   float64
#  9   Deliverable Quantity       2465 non-null   float64
#  10  % Deli. Qty to Traded Qty  2465 non-null   float64
#  11  Spread High-Low            2473 non-null   float64
#  12  Spread Close-Open          2473 non-null   float64
# dtypes: float64(10), int64(2), object(1)
# memory usage: 251.3+ KB
# None
#
# ==================================================
#
# Stock Code: 523832
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1046 entries, 0 to 1045
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       1046 non-null   object
#  1   Open Price                 1046 non-null   float64
#  2   High Price                 1046 non-null   float64
#  3   Low Price                  1046 non-null   float64
#  4   Close Price                1046 non-null   float64
#  5   WAP                        1046 non-null   float64
#  6   No.of Shares               1046 non-null   int64
#  7   No. of Trades              1046 non-null   int64
#  8   Total Turnover (Rs.)       1046 non-null   float64
#  9   Deliverable Quantity       1046 non-null   int64
#  10  % Deli. Qty to Traded Qty  1046 non-null   float64
#  11  Spread High-Low            1046 non-null   float64
#  12  Spread Close-Open          1046 non-null   float64
# dtypes: float64(9), int64(3), object(1)
# memory usage: 106.4+ KB
# None
#
# ==================================================
#
# Stock Code: 512437
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2079 entries, 0 to 2078
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       2079 non-null   object
#  1   Open Price                 2079 non-null   float64
#  2   High Price                 2079 non-null   float64
#  3   Low Price                  2079 non-null   float64
#  4   Close Price                2079 non-null   float64
#  5   WAP                        2079 non-null   float64
#  6   No.of Shares               2079 non-null   int64
#  7   No. of Trades              2079 non-null   int64
#  8   Total Turnover (Rs.)       2079 non-null   float64
#  9   Deliverable Quantity       2078 non-null   float64
#  10  % Deli. Qty to Traded Qty  2078 non-null   float64
#  11  Spread High-Low            2079 non-null   float64
#  12  Spread Close-Open          2079 non-null   float64
# dtypes: float64(10), int64(2), object(1)
# memory usage: 211.3+ KB
# None
#
# ==================================================
#
# Stock Code: 513729
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2438 entries, 0 to 2437
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       2438 non-null   object
#  1   Open Price                 2438 non-null   float64
#  2   High Price                 2438 non-null   float64
#  3   Low Price                  2438 non-null   float64
#  4   Close Price                2438 non-null   float64
#  5   WAP                        2438 non-null   float64
#  6   No.of Shares               2438 non-null   int64
#  7   No. of Trades              2438 non-null   int64
#  8   Total Turnover (Rs.)       2438 non-null   float64
#  9   Deliverable Quantity       2437 non-null   float64
#  10  % Deli. Qty to Traded Qty  2437 non-null   float64
#  11  Spread High-Low            2438 non-null   float64
#  12  Spread Close-Open          2438 non-null   float64
# dtypes: float64(10), int64(2), object(1)
# memory usage: 247.7+ KB
# None
#
# ==================================================
#
# Stock Code: 522292
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2052 entries, 0 to 2051
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       2052 non-null   object
#  1   Open Price                 2052 non-null   float64
#  2   High Price                 2052 non-null   float64
#  3   Low Price                  2052 non-null   float64
#  4   Close Price                2052 non-null   float64
#  5   WAP                        2052 non-null   float64
#  6   No.of Shares               2052 non-null   int64
#  7   No. of Trades              2052 non-null   int64
#  8   Total Turnover (Rs.)       2052 non-null   float64
#  9   Deliverable Quantity       2052 non-null   int64
#  10  % Deli. Qty to Traded Qty  2052 non-null   float64
#  11  Spread High-Low            2052 non-null   float64
#  12  Spread Close-Open          2052 non-null   float64
# dtypes: float64(9), int64(3), object(1)
# memory usage: 208.5+ KB
# None
#
# ==================================================

# %%
# Analyze the first dataframe in detail
first_stock_code = next(iter(all_data))
df = all_data[first_stock_code]

print(f"\nDetailed analysis for Stock Code: {first_stock_code}")
display(df.head())
display(df.describe())

# Check for missing values
print("\nMissing Values:")
display(df.isnull().sum())
# Out:
# Detailed analysis for Stock Code: 500033
#              Date  Open Price  High Price  Low Price  Close Price  \
# 0  28-August-2023     3498.80     3506.45    3404.00      3415.00
# 1  25-August-2023     3599.95     3649.25    3396.00      3441.85
# 2  24-August-2023     3454.95     3573.45    3422.95      3573.45
# 3  23-August-2023     3419.95     3451.00    3383.00      3403.30
# 4  22-August-2023     3429.00     3429.00    3380.00      3402.60
#
#            WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 0  3447.860488          3032            701            10453913.0
# 1  3515.589407          5721           1176            20112687.0
# 2  3552.271658          8842            602            31409186.0
# 3  3408.239115          1401            307             4774943.0
# 4  3400.747967          1230            318             4182920.0
#
#    Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 0                1600.0                      52.77           102.45
# 1                2452.0                      42.86           253.25
# 2                6342.0                      71.73           150.50
# 3                 826.0                      58.96            68.00
# 4                 514.0                      41.79            49.00
#
#    Spread Close-Open
# 0             -83.80
# 1            -158.10
# 2             118.50
# 3             -16.65
# 4             -26.40
#         Open Price   High Price    Low Price  Close Price          WAP  \
# count  2473.000000  2473.000000  2473.000000  2473.000000  2473.000000
# mean   1882.041569  1918.684351  1849.827194  1877.695512  1884.904160
# std    1139.886509  1157.389304  1125.219261  1138.239596  1141.804897
# min     268.450000   280.000000   268.050000   277.000000   275.217765
# 25%    1105.000000  1132.700000  1084.750000  1101.050000  1108.160326
# 50%    1420.000000  1444.000000  1392.000000  1413.250000  1421.115832
# 75%    2790.000000  2839.000000  2752.000000  2782.200000  2790.568338
# max    4699.000000  4839.000000  4666.350000  4716.050000  4738.221960
#
#        No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# count  2.473000e+03    2473.000000          2.473000e+03
# mean   5.536018e+04    4114.734331          1.240180e+08
# std    1.254294e+05    7049.976834          2.760996e+08
# min    6.700000e+01      13.000000          1.851300e+04
# 25%    4.507000e+03     712.000000          5.259462e+06
# 50%    1.435900e+04    1661.000000          2.434362e+07
# 75%    4.964200e+04    4348.000000          1.210311e+08
# max    1.774086e+06   79747.000000          3.644472e+09
#
#        Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# count           2465.000000                2465.000000      2473.000000
# mean           17981.019473                  44.541878        68.857157
# std            36945.351954                  15.357900        57.317878
# min               26.000000                   9.470000         0.000000
# 25%             2088.000000                  32.910000        33.050000
# 50%             6351.000000                  43.510000        53.950000
# 75%            19058.000000                  54.670000        86.500000
# max           718575.000000                 100.000000       730.000000
#
#        Spread Close-Open
# count        2473.000000
# mean           -4.346057
# std            53.542437
# min          -414.500000
# 25%           -26.450000
# 50%            -7.000000
# 75%            11.500000
# max           531.000000
# Missing Values:
# Date                         0
# Open Price                   0
# High Price                   0
# Low Price                    0
# Close Price                  0
# WAP                          0
# No.of Shares                 0
# No. of Trades                0
# Total Turnover (Rs.)         0
# Deliverable Quantity         8
# % Deli. Qty to Traded Qty    8
# Spread High-Low              0
# Spread Close-Open            0
# dtype: int64

# %%
# Create a correlation heatmap for numerical columns
plt.figure(figsize=(12, 10))
sns.heatmap(df.select_dtypes(include=[np.number]).corr(), annot=True, cmap='coolwarm')
plt.title(f'Correlation Heatmap of Numerical Features for Stock {first_stock_code}')
plt.show()

# %%
# Visualize the distribution of closing prices
plt.figure(figsize=(10, 6))
sns.histplot(df['Close Price'], kde=True)
plt.title(f'Distribution of Closing Prices for Stock {first_stock_code}')
plt.show()

# %%
# Plot the closing price over time
plt.figure(figsize=(12, 6))
plt.plot(pd.to_datetime(df['Date']), df['Close Price'])
plt.title(f'Closing Price Over Time for Stock {first_stock_code}')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.xticks(rotation=45)
plt.show()
